# %% [markdown]
# <a href="https://colab.research.google.com/github/bejoyjose1993/Deep-Learning/blob/master/Text_Reconstruction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **PART 1 - Text Reconstruction Application**

# %% [markdown]
# ---

# %% [markdown]
# # **Dence Network**

# %% [markdown]
# **Basic Dense Network**

# %% [markdown]
# --

# %%
#importing the libraries 
from __future__ import absolute_import, division, print_function, unicode_literals
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.datasets import mnist

print('TensorFlow version:', tf.__version__)
print('Is Executing Eagerly?', tf.executing_eagerly())

#Define an encoder layer
class Encoder(tf.keras.layers.Layer):
    def __init__(self, intermediate_dim):
        super(Encoder, self).__init__()
        self.hidden_layer = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
        self.output_layer = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
    
    def call(self, input_features):
        activation = self.hidden_layer(input_features)
        return self.output_layer(activation)

#Define a decoder layer
class Decoder(tf.keras.layers.Layer):
    def __init__(self, intermediate_dim, original_dim):
        super(Decoder, self).__init__()
        self.hidden_layer = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
        self.output_layer = tf.keras.layers.Dense(units=original_dim, activation=tf.nn.relu)
  
    def call(self, code):
        activation = self.hidden_layer(code)
        return self.output_layer(activation)

#Build the autoencoder model
class Autoencoder(tf.keras.Model):
  def __init__(self, intermediate_dim, original_dim):
    super(Autoencoder, self).__init__()
    self.loss = []
    self.encoder = Encoder(intermediate_dim=intermediate_dim)
    self.decoder = Decoder(intermediate_dim=intermediate_dim, original_dim=original_dim)

  def call(self, input_features):
    code = self.encoder(input_features)
    reconstructed = self.decoder(code)
    return reconstructed

#Reconstruction Loss error
def loss(preds, real):
  return tf.reduce_mean(tf.square(tf.subtract(preds, real)))

#Forward pass and optimization
def train(loss, model, opt, original):
  with tf.GradientTape() as tape:
    preds = model(original)
    reconstruction_error = loss(preds, original)
  gradients = tape.gradient(reconstruction_error, model.trainable_variables)
  gradient_variables = zip(gradients, model.trainable_variables)
  opt.apply_gradients(gradient_variables)
  
  return reconstruction_error

#The training loop
def train_loop(model, opt, loss, dataset, epochs):
  for epoch in range(epochs):
    epoch_loss = 0
    for step, batch_features in enumerate(dataset):
      loss_values = train(loss, model, opt, batch_features)
      epoch_loss += loss_values
    model.loss.append(epoch_loss)
    print('Epoch {}/{}. Loss: {}'.format(epoch + 1, epochs, epoch_loss.numpy()))  

#Process the dataset    
from sklearn.metrics import accuracy_score

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train / 255.

x_train = x_train.astype(np.float32)
x_train = np.reshape(x_train, (x_train.shape[0], 784))
x_test = np.reshape(x_test, (x_test.shape[0], 784))


training_dataset = tf.data.Dataset.from_tensor_slices(x_train).batch(256)

# Basic Model Call
model = Autoencoder(intermediate_dim=128, original_dim=784)
opt = tf.keras.optimizers.Adam(learning_rate=1e-2)
train_loop(model, opt, loss, training_dataset, 20)


#Plot the loss Vs Epoch
plt.plot(range(20), model.loss)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()
#learning_rate=1e-3 ,intermediate_dim=512


#Prediction Output
number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(model(x_test)[index].numpy().reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
#learning_rate=1e-3 ,intermediate_dim=512
# Out:
# TensorFlow version: 2.2.0-rc2
# Is Executing Eagerly? True
# Epoch 1/20. Loss: 9.389966011047363
# Epoch 2/20. Loss: 5.975910186767578
# Epoch 3/20. Loss: 5.484451770782471
# Epoch 4/20. Loss: 5.2382659912109375
# Epoch 5/20. Loss: 5.132998466491699
# Epoch 6/20. Loss: 5.04633903503418
# Epoch 7/20. Loss: 4.987010955810547
# Epoch 8/20. Loss: 4.928111553192139
# Epoch 9/20. Loss: 4.887776851654053
# Epoch 10/20. Loss: 4.871705055236816
# Epoch 11/20. Loss: 4.825455665588379
# Epoch 12/20. Loss: 4.8199782371521
# Epoch 13/20. Loss: 4.809317111968994
# Epoch 14/20. Loss: 4.781755447387695
# Epoch 15/20. Loss: 4.780313968658447
# Epoch 16/20. Loss: 4.7605109214782715
# Epoch 17/20. Loss: 4.74934720993042
# Epoch 18/20. Loss: 4.7496442794799805
# Epoch 19/20. Loss: 4.73276948928833
# Epoch 20/20. Loss: 4.735046863555908

# %% [markdown]
# ---

# %% [markdown]
# --

# %% [markdown]
# **Complex Dense Network- Best (Model 1)**

# %%
#importing the libraries 
from __future__ import absolute_import, division, print_function, unicode_literals
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.datasets import mnist

print('TensorFlow version:', tf.__version__)
print('Is Executing Eagerly?', tf.executing_eagerly())

#Define an encoder layer
class Encoder(tf.keras.layers.Layer):
    def __init__(self, intermediate_dim):
        super(Encoder, self).__init__()
        self.hidden_layer = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.sigmoid)
        self.output_layer = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.sigmoid)
    
    def call(self, input_features):
        activation = self.hidden_layer(input_features)
        return self.output_layer(activation)

#Define a decoder layer
class Decoder(tf.keras.layers.Layer):
    def __init__(self, intermediate_dim, original_dim):
        super(Decoder, self).__init__()
        self.hidden_layer = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.sigmoid)
        self.output_layer = tf.keras.layers.Dense(units=original_dim, activation=tf.nn.sigmoid)
  
    def call(self, code):
        activation = self.hidden_layer(code)
        return self.output_layer(activation)

#Build the autoencoder model
class Autoencoder(tf.keras.Model):
  def __init__(self, intermediate_dim, original_dim):
    super(Autoencoder, self).__init__()
    self.loss = []
    self.encoder = Encoder(intermediate_dim=intermediate_dim)
    self.decoder = Decoder(intermediate_dim=intermediate_dim, original_dim=original_dim)

  def call(self, input_features):
    code = self.encoder(input_features)
    reconstructed = self.decoder(code)
    return reconstructed

#Reconstruction Loss error
def loss(preds, real):
  return tf.reduce_mean(tf.square(tf.subtract(preds, real)))

#Forward pass and optimization
def train(loss, model, opt, original):
  with tf.GradientTape() as tape:
    preds = model(original)
    reconstruction_error = loss(preds, original)
  gradients = tape.gradient(reconstruction_error, model.trainable_variables)
  gradient_variables = zip(gradients, model.trainable_variables)
  opt.apply_gradients(gradient_variables)
  
  return reconstruction_error

#The training loop
def train_loop(model, opt, loss, dataset, epochs):
  for epoch in range(epochs):
    epoch_loss = 0
    for step, batch_features in enumerate(dataset):
      loss_values = train(loss, model, opt, batch_features)
      epoch_loss += loss_values
    model.loss.append(epoch_loss)
    print('Epoch {}/{}. Loss: {}'.format(epoch + 1, epochs, epoch_loss.numpy()))  

#Process the dataset    
from sklearn.metrics import accuracy_score

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train / 255.

x_train = x_train.astype(np.float32)
x_train = np.reshape(x_train, (x_train.shape[0], 784))
x_test = np.reshape(x_test, (x_test.shape[0], 784))


training_dataset = tf.data.Dataset.from_tensor_slices(x_train).batch(256)



# Complex Model By changing intermediate layer and learning reates
model = Autoencoder(intermediate_dim=512, original_dim=784)
opt = tf.keras.optimizers.Adam(learning_rate=1e-3)
train_loop(model, opt, loss, training_dataset, 20)


#Plot the loss Vs Epoch
plt.plot(range(20), model.loss)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()
#learning_rate=1e-3 ,intermediate_dim=512


#Prediction Output
number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(model(x_test)[index].numpy().reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
#learning_rate=1e-3 ,intermediate_dim=512
# Out:
# TensorFlow version: 2.2.0-rc2
# Is Executing Eagerly? True
# Epoch 1/20. Loss: 15.861479759216309
# Epoch 2/20. Loss: 10.415462493896484
# Epoch 3/20. Loss: 7.708052635192871
# Epoch 4/20. Loss: 6.059676647186279
# Epoch 5/20. Loss: 5.004060745239258
# Epoch 6/20. Loss: 4.250009059906006
# Epoch 7/20. Loss: 3.6833529472351074
# Epoch 8/20. Loss: 3.2489845752716064
# Epoch 9/20. Loss: 2.9330310821533203
# Epoch 10/20. Loss: 2.6813454627990723
# Epoch 11/20. Loss: 2.477851390838623
# Epoch 12/20. Loss: 2.303541421890259
# Epoch 13/20. Loss: 2.1471357345581055
# Epoch 14/20. Loss: 2.0108065605163574
# Epoch 15/20. Loss: 1.8912996053695679
# Epoch 16/20. Loss: 1.7850067615509033
# Epoch 17/20. Loss: 1.6906566619873047
# Epoch 18/20. Loss: 1.6064984798431396
# Epoch 19/20. Loss: 1.530874490737915
# Epoch 20/20. Loss: 1.4626356363296509

# %% [markdown]
# --

# %% [markdown]
# **Complex Dense Network- Best (Model 2)**

# %%
#importing the libraries 
from __future__ import absolute_import, division, print_function, unicode_literals
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.datasets import mnist

print('TensorFlow version:', tf.__version__)
print('Is Executing Eagerly?', tf.executing_eagerly())

#Define an encoder layer
class Encoder(tf.keras.layers.Layer):
    def __init__(self, intermediate_dim):
        super(Encoder, self).__init__()
        self.hidden_layer = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
        self.output_layer = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
    
    def call(self, input_features):
        activation = self.hidden_layer(input_features)
        return self.output_layer(activation)

#Define a decoder layer
class Decoder(tf.keras.layers.Layer):
    def __init__(self, intermediate_dim, original_dim):
        super(Decoder, self).__init__()
        self.hidden_layer = tf.keras.layers.Dense(units=intermediate_dim, activation=tf.nn.relu)
        self.output_layer = tf.keras.layers.Dense(units=original_dim, activation=tf.nn.relu)
  
    def call(self, code):
        activation = self.hidden_layer(code)
        return self.output_layer(activation)

#Build the autoencoder model
class Autoencoder(tf.keras.Model):
  def __init__(self, intermediate_dim, original_dim):
    super(Autoencoder, self).__init__()
    self.loss = []
    self.encoder = Encoder(intermediate_dim=intermediate_dim)
    self.decoder = Decoder(intermediate_dim=intermediate_dim, original_dim=original_dim)

  def call(self, input_features):
    code = self.encoder(input_features)
    reconstructed = self.decoder(code)
    return reconstructed

#Reconstruction Loss error
def loss(preds, real):
  return tf.reduce_mean(tf.square(tf.subtract(preds, real)))

#Forward pass and optimization
def train(loss, model, opt, original):
  with tf.GradientTape() as tape:
    preds = model(original)
    reconstruction_error = loss(preds, original)
  gradients = tape.gradient(reconstruction_error, model.trainable_variables)
  gradient_variables = zip(gradients, model.trainable_variables)
  opt.apply_gradients(gradient_variables)
  
  return reconstruction_error

#The training loop
def train_loop(model, opt, loss, dataset, epochs):
  for epoch in range(epochs):
    epoch_loss = 0
    for step, batch_features in enumerate(dataset):
      loss_values = train(loss, model, opt, batch_features)
      epoch_loss += loss_values
    model.loss.append(epoch_loss)
    print('Epoch {}/{}. Loss: {}'.format(epoch + 1, epochs, epoch_loss.numpy()))  

#Process the dataset    
from sklearn.metrics import accuracy_score

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train / 255.

x_train = x_train.astype(np.float32)
x_train = np.reshape(x_train, (x_train.shape[0], 784))
x_test = np.reshape(x_test, (x_test.shape[0], 784))


training_dataset = tf.data.Dataset.from_tensor_slices(x_train).batch(256)
# Complex Model By changing intermediate layer and learning reates
model = Autoencoder(intermediate_dim=512, original_dim=784)
opt = tf.keras.optimizers.Adam(learning_rate=1e-3)
train_loop(model, opt, loss, training_dataset, 20)


#Plot the loss Vs Epoch
plt.plot(range(20), model.loss)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()
#learning_rate=1e-3 ,intermediate_dim=512


#Prediction Output
number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(model(x_test)[index].numpy().reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
#learning_rate=1e-3 ,intermediate_dim=512
# Out:
# TensorFlow version: 2.2.0-rc2
# Is Executing Eagerly? True
# Epoch 1/20. Loss: 4.811588287353516
# Epoch 2/20. Loss: 2.061939001083374
# Epoch 3/20. Loss: 1.634281873703003
# Epoch 4/20. Loss: 1.4456558227539062
# Epoch 5/20. Loss: 1.3493993282318115
# Epoch 6/20. Loss: 1.2483686208724976
# Epoch 7/20. Loss: 1.2221087217330933
# Epoch 8/20. Loss: 1.1833029985427856
# Epoch 9/20. Loss: 1.1490882635116577
# Epoch 10/20. Loss: 1.1444348096847534
# Epoch 11/20. Loss: 1.1046807765960693
# Epoch 12/20. Loss: 1.0857688188552856
# Epoch 13/20. Loss: 1.064314365386963
# Epoch 14/20. Loss: 1.0498396158218384
# Epoch 15/20. Loss: 1.0958566665649414
# Epoch 16/20. Loss: 1.023940920829773
# Epoch 17/20. Loss: 1.028550148010254
# Epoch 18/20. Loss: 1.016374111175537
# Epoch 19/20. Loss: 1.03224515914917
# Epoch 20/20. Loss: 1.0020016431808472

# %% [markdown]
# ---

# %% [markdown]
# ***CNN MODELS***

# %% [markdown]
# ---

# %% [markdown]
# --

# %% [markdown]
# Basic CNN MODEL Filter Size (16,8,8) Kernal (3,3)

# %%
input_img = tf.keras.layers.Input(shape=(28, 28, 1)) # adapt this if using `channels_first` image data format

x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
decoded = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = tf.keras.models.Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')


# to train this model we will with original MNIST digits with shape (samples, 3, 28, 28) and we will just normalize pixel values between 0 and 1
# (x_train, _), (x_test, _) = load_data('../input/mnist.npz')
from tensorflow.keras.datasets import mnist
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

history = autoencoder.fit(x_train, x_train, epochs=50, batch_size=128, 
                shuffle=True, validation_data=(x_test, x_test), 
                callbacks=[tf.keras.callbacks.TensorBoard(log_dir='./tmp/autoencoder')])




# For Displaying Plot
plt.plot(range(50), history.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# For Displaying Output
pred = autoencoder.predict(x_test)
pred = autoencoder.predict(x_test)
number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(pred[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Epoch 1/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.6924 - val_loss: 0.6894
# Epoch 2/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.6859 - val_loss: 0.6820
# Epoch 3/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.6767 - val_loss: 0.6703
# Epoch 4/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.6598 - val_loss: 0.6462
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.6194 - val_loss: 0.5831
# Epoch 6/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5330 - val_loss: 0.4969
# Epoch 7/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4833 - val_loss: 0.4810
# Epoch 8/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4726 - val_loss: 0.4724
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4643 - val_loss: 0.4641
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4560 - val_loss: 0.4556
# Epoch 11/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4473 - val_loss: 0.4464
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4378 - val_loss: 0.4361
# Epoch 13/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4271 - val_loss: 0.4245
# Epoch 14/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4149 - val_loss: 0.4111
# Epoch 15/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4006 - val_loss: 0.3953
# Epoch 16/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3839 - val_loss: 0.3769
# Epoch 17/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3649 - val_loss: 0.3564
# Epoch 18/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3443 - val_loss: 0.3350
# Epoch 19/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3238 - val_loss: 0.3149
# Epoch 20/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3053 - val_loss: 0.2977
# Epoch 21/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2902 - val_loss: 0.2842
# Epoch 22/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2788 - val_loss: 0.2744
# Epoch 23/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2704 - val_loss: 0.2672
# Epoch 24/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2644 - val_loss: 0.2620
# Epoch 25/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2599 - val_loss: 0.2581
# Epoch 26/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2563 - val_loss: 0.2548
# Epoch 27/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2534 - val_loss: 0.2521
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2510 - val_loss: 0.2498
# Epoch 29/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2488 - val_loss: 0.2478
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2469 - val_loss: 0.2459
# Epoch 31/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2452 - val_loss: 0.2443
# Epoch 32/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2436 - val_loss: 0.2427
# Epoch 33/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2421 - val_loss: 0.2413
# Epoch 34/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2408 - val_loss: 0.2400
# Epoch 35/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2395 - val_loss: 0.2387
# Epoch 36/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2383 - val_loss: 0.2375
# Epoch 37/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2371 - val_loss: 0.2364
# Epoch 38/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2360 - val_loss: 0.2353
# Epoch 39/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2349 - val_loss: 0.2342
# Epoch 40/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2339 - val_loss: 0.2332
# Epoch 41/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2329 - val_loss: 0.2322
# Epoch 42/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2319 - val_loss: 0.2312
# Epoch 43/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2310 - val_loss: 0.2303
# Epoch 44/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2301 - val_loss: 0.2294
# Epoch 45/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2292 - val_loss: 0.2285
# Epoch 46/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2283 - val_loss: 0.2277
# Epoch 47/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2275 - val_loss: 0.2269
# Epoch 48/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2267 - val_loss: 0.2261
# Epoch 49/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2259 - val_loss: 0.2253
# Epoch 50/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2252 - val_loss: 0.2245

# %% [markdown]
# ---

# %% [markdown]
# --

# %% [markdown]
# **Complex CNN MODEL Filter Size (64,32,32,32) Kernal (3,3)**

# %%
input_img = tf.keras.layers.Input(shape=(28, 28, 1)) # adapt this if using `channels_first` image data format

# Changing Kernal Size
x = tf.keras.layers.Conv2D(64, (5, 5), activation='relu', padding='same')(input_img)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
#x = tf.keras.layers.Conv2D(32, (5, 5), activation='relu', padding='same')(x) #Changing Kernal Size
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
#x = tf.keras.layers.Conv2D(32, (5, 5), activation='relu', padding='same')(x) #Changing Kernal Size
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
#x = tf.keras.layers.Conv2D(32, (5, 5), activation='relu', padding='same')(x) #Changing Kernal Size
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x) 
x = tf.keras.layers.UpSampling2D((2, 2))(x)
#x = tf.keras.layers.Conv2D(32, (5, 5), activation='relu', padding='same')(x) #Changing Kernal Size
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x) 
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu')(x) 
x = tf.keras.layers.UpSampling2D((2, 2))(x)
decoded = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = tf.keras.models.Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary()


# to train this model we will with original MNIST digits with shape (samples, 3, 28, 28) and we will just normalize pixel values between 0 and 1
# (x_train, _), (x_test, _) = load_data('../input/mnist.npz')
from tensorflow.keras.datasets import mnist
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

history = autoencoder.fit(x_train, x_train, epochs=50, batch_size=128, 
                shuffle=True, validation_data=(x_test, x_test), 
                callbacks=[tf.keras.callbacks.TensorBoard(log_dir='./tmp/autoencoder')])




# For Displaying Plot
plt.plot(range(50), history.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# For Displaying Output
pred = autoencoder.predict(x_test)
pred = autoencoder.predict(x_test)
number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(pred[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 28, 28, 64)        1664
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 14, 14, 32)        18464
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 7, 7, 32)          9248
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 4, 4, 32)          9248
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 2, 2, 32)          9248
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 4, 4, 32)          9248
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 8, 8, 32)          9248
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 14, 14, 64)        18496
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 28, 28, 1)         577
# =================================================================
# Total params: 85,441
# Trainable params: 85,441
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 6s 13ms/step - loss: 0.6941 - val_loss: 0.6920
# Epoch 2/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.6893 - val_loss: 0.6861
# Epoch 3/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.6815 - val_loss: 0.6761
# Epoch 4/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.6673 - val_loss: 0.6559
# Epoch 5/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.6319 - val_loss: 0.5974
# Epoch 6/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.5303 - val_loss: 0.4657
# Epoch 7/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.4418 - val_loss: 0.4355
# Epoch 8/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.4245 - val_loss: 0.4210
# Epoch 9/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.4082 - val_loss: 0.4013
# Epoch 10/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3827 - val_loss: 0.3673
# Epoch 11/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3428 - val_loss: 0.3245
# Epoch 12/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3098 - val_loss: 0.2999
# Epoch 13/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2917 - val_loss: 0.2862
# Epoch 14/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2819 - val_loss: 0.2786
# Epoch 15/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2762 - val_loss: 0.2740
# Epoch 16/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2726 - val_loss: 0.2709
# Epoch 17/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2699 - val_loss: 0.2685
# Epoch 18/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2678 - val_loss: 0.2666
# Epoch 19/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2660 - val_loss: 0.2650
# Epoch 20/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2644 - val_loss: 0.2635
# Epoch 21/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2630 - val_loss: 0.2621
# Epoch 22/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2616 - val_loss: 0.2607
# Epoch 23/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2603 - val_loss: 0.2595
# Epoch 24/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2591 - val_loss: 0.2583
# Epoch 25/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2579 - val_loss: 0.2572
# Epoch 26/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2569 - val_loss: 0.2562
# Epoch 27/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2560 - val_loss: 0.2553
# Epoch 28/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2551 - val_loss: 0.2545
# Epoch 29/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2543 - val_loss: 0.2537
# Epoch 30/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2535 - val_loss: 0.2530
# Epoch 31/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2528 - val_loss: 0.2523
# Epoch 32/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2521 - val_loss: 0.2516
# Epoch 33/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2515 - val_loss: 0.2510
# Epoch 34/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2509 - val_loss: 0.2505
# Epoch 35/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2504 - val_loss: 0.2499
# Epoch 36/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2498 - val_loss: 0.2493
# Epoch 37/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2493 - val_loss: 0.2488
# Epoch 38/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2487 - val_loss: 0.2483
# Epoch 39/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2482 - val_loss: 0.2478
# Epoch 40/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2477 - val_loss: 0.2473
# Epoch 41/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2472 - val_loss: 0.2467
# Epoch 42/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2466 - val_loss: 0.2462
# Epoch 43/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2461 - val_loss: 0.2457
# Epoch 44/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2456 - val_loss: 0.2452
# Epoch 45/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2451 - val_loss: 0.2447
# Epoch 46/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2446 - val_loss: 0.2442
# Epoch 47/50
# 469/469 [==============================] - 5s 12ms/step - loss: 0.2441 - val_loss: 0.2437
# Epoch 48/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2435 - val_loss: 0.2431
# Epoch 49/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2430 - val_loss: 0.2426
# Epoch 50/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2425 - val_loss: 0.2421

# %% [markdown]
# ---

# %% [markdown]
# --

# %% [markdown]
# **Complex CNN MODEL Filter Size (128,64,64) Kernal (3,3)**

# %%
from keras import regularizers
input_img = tf.keras.layers.Input(shape=(28, 28, 1)) # adapt this if using `channels_first` image data format


x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(input_img)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
decoded = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = tf.keras.models.Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy', metrics="accuracy")
autoencoder.summary()

#Importing Data
from tensorflow.keras.datasets import mnist
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

#Calling Model
history = autoencoder.fit(x_train, x_train, epochs=50, batch_size=128, 
                shuffle=True, validation_data=(x_test, x_test), 
                callbacks=[tf.keras.callbacks.TensorBoard(log_dir='./tmp/autoencoder')])

# Plot Graph
plt.plot(range(50), history.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# Input V/S Output
pred = autoencoder.predict(x_test)
pred = autoencoder.predict(x_test)
number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(pred[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 28, 28, 128)       1280
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 14, 14, 64)        73792
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 7, 7, 32)          18464
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 4, 4, 32)          9248
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 8, 8, 64)          18496
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 14, 14, 128)       73856
# _________________________________________________________________
# up_sampling2d_9 (UpSampling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 28, 28, 1)         1153
# =================================================================
# Total params: 196,289
# Trainable params: 196,289
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 10s 20ms/step - loss: 0.6923 - accuracy: 0.4997 - val_loss: 0.6886 - val_accuracy: 0.7963
# Epoch 2/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.6826 - accuracy: 0.8078 - val_loss: 0.6740 - val_accuracy: 0.8072
# Epoch 3/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.6493 - accuracy: 0.8088 - val_loss: 0.6054 - val_accuracy: 0.8072
# Epoch 4/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.5212 - accuracy: 0.8088 - val_loss: 0.4745 - val_accuracy: 0.8072
# Epoch 5/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.4625 - accuracy: 0.8088 - val_loss: 0.4592 - val_accuracy: 0.8072
# Epoch 6/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.4477 - accuracy: 0.8088 - val_loss: 0.4445 - val_accuracy: 0.8072
# Epoch 7/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.4330 - accuracy: 0.8088 - val_loss: 0.4291 - val_accuracy: 0.8072
# Epoch 8/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.4166 - accuracy: 0.8088 - val_loss: 0.4108 - val_accuracy: 0.8072
# Epoch 9/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.3957 - accuracy: 0.8088 - val_loss: 0.3865 - val_accuracy: 0.8072
# Epoch 10/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.3688 - accuracy: 0.8088 - val_loss: 0.3567 - val_accuracy: 0.8072
# Epoch 11/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.3394 - accuracy: 0.8088 - val_loss: 0.3283 - val_accuracy: 0.8072
# Epoch 12/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.3135 - accuracy: 0.8088 - val_loss: 0.3041 - val_accuracy: 0.8072
# Epoch 13/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2914 - accuracy: 0.8088 - val_loss: 0.2835 - val_accuracy: 0.8072
# Epoch 14/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2733 - accuracy: 0.8088 - val_loss: 0.2671 - val_accuracy: 0.8072
# Epoch 15/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2592 - accuracy: 0.8073 - val_loss: 0.2547 - val_accuracy: 0.8022
# Epoch 16/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2489 - accuracy: 0.7988 - val_loss: 0.2458 - val_accuracy: 0.7918
# Epoch 17/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2415 - accuracy: 0.7896 - val_loss: 0.2394 - val_accuracy: 0.7849
# Epoch 18/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2361 - accuracy: 0.7842 - val_loss: 0.2346 - val_accuracy: 0.7811
# Epoch 19/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2320 - accuracy: 0.7814 - val_loss: 0.2309 - val_accuracy: 0.7794
# Epoch 20/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2286 - accuracy: 0.7802 - val_loss: 0.2277 - val_accuracy: 0.7789
# Epoch 21/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2257 - accuracy: 0.7798 - val_loss: 0.2250 - val_accuracy: 0.7787
# Epoch 22/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2232 - accuracy: 0.7799 - val_loss: 0.2226 - val_accuracy: 0.7791
# Epoch 23/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2209 - accuracy: 0.7803 - val_loss: 0.2203 - val_accuracy: 0.7798
# Epoch 24/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2187 - accuracy: 0.7811 - val_loss: 0.2181 - val_accuracy: 0.7805
# Epoch 25/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2166 - accuracy: 0.7819 - val_loss: 0.2160 - val_accuracy: 0.7813
# Epoch 26/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2145 - accuracy: 0.7829 - val_loss: 0.2140 - val_accuracy: 0.7824
# Epoch 27/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2125 - accuracy: 0.7840 - val_loss: 0.2120 - val_accuracy: 0.7834
# Epoch 28/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2106 - accuracy: 0.7850 - val_loss: 0.2100 - val_accuracy: 0.7845
# Epoch 29/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2087 - accuracy: 0.7860 - val_loss: 0.2081 - val_accuracy: 0.7856
# Epoch 30/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2068 - accuracy: 0.7871 - val_loss: 0.2062 - val_accuracy: 0.7867
# Epoch 31/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.2050 - accuracy: 0.7883 - val_loss: 0.2044 - val_accuracy: 0.7879
# Epoch 32/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2032 - accuracy: 0.7894 - val_loss: 0.2026 - val_accuracy: 0.7890
# Epoch 33/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2015 - accuracy: 0.7903 - val_loss: 0.2009 - val_accuracy: 0.7898
# Epoch 34/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1999 - accuracy: 0.7910 - val_loss: 0.1993 - val_accuracy: 0.7903
# Epoch 35/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1984 - accuracy: 0.7916 - val_loss: 0.1978 - val_accuracy: 0.7909
# Epoch 36/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1970 - accuracy: 0.7921 - val_loss: 0.1964 - val_accuracy: 0.7915
# Epoch 37/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1957 - accuracy: 0.7925 - val_loss: 0.1951 - val_accuracy: 0.7920
# Epoch 38/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1945 - accuracy: 0.7929 - val_loss: 0.1938 - val_accuracy: 0.7922
# Epoch 39/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1933 - accuracy: 0.7932 - val_loss: 0.1927 - val_accuracy: 0.7926
# Epoch 40/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1922 - accuracy: 0.7935 - val_loss: 0.1916 - val_accuracy: 0.7929
# Epoch 41/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1912 - accuracy: 0.7938 - val_loss: 0.1906 - val_accuracy: 0.7931
# Epoch 42/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1902 - accuracy: 0.7940 - val_loss: 0.1896 - val_accuracy: 0.7934
# Epoch 43/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1893 - accuracy: 0.7942 - val_loss: 0.1887 - val_accuracy: 0.7935
# Epoch 44/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1884 - accuracy: 0.7944 - val_loss: 0.1878 - val_accuracy: 0.7938
# Epoch 45/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1875 - accuracy: 0.7946 - val_loss: 0.1869 - val_accuracy: 0.7941
# Epoch 46/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1867 - accuracy: 0.7947 - val_loss: 0.1861 - val_accuracy: 0.7944
# Epoch 47/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1859 - accuracy: 0.7949 - val_loss: 0.1853 - val_accuracy: 0.7944
# Epoch 48/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1851 - accuracy: 0.7951 - val_loss: 0.1845 - val_accuracy: 0.7945
# Epoch 49/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1843 - accuracy: 0.7952 - val_loss: 0.1837 - val_accuracy: 0.7947
# Epoch 50/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1836 - accuracy: 0.7954 - val_loss: 0.1829 - val_accuracy: 0.7949

# %% [markdown]
# ---

# %% [markdown]
# --

# %% [markdown]
# **Complex CNN MODEL Filter Size (128,64,64) Kernal (3,3)** With keras.library

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model
from keras import backend as K

input_img = Input(shape=(28, 28, 1))  # adapt this if using `channels_first` image data format

x = Conv2D(128, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary()

from tensorflow.keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))  # adapt this if using `channels_first` image data format
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))  # adapt this if using `channels_first` image data format


from keras.callbacks import TensorBoard

history = autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/autoencoder')])


# Plot Graph
plt.plot(range(100), history.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# Input V/S Output
pred = autoencoder.predict(x_test)
pred = autoencoder.predict(x_test)
number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(pred[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 28, 28, 128)       1280
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 14, 14, 64)        73792
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 7, 7, 32)          18464
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 4, 4, 32)          9248
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 8, 8, 64)          18496
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 14, 14, 128)       73856
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 28, 28, 1)         1153
# =================================================================
# Total params: 196,289
# Trainable params: 196,289
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.1826 - val_loss: 0.1395
# Epoch 2/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.1223 - val_loss: 0.1121
# Epoch 3/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.1095 - val_loss: 0.1080
# Epoch 4/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.1022 - val_loss: 0.0997
# Epoch 5/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0970 - val_loss: 0.0927
# Epoch 6/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0933 - val_loss: 0.0920
# Epoch 7/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0904 - val_loss: 0.0863
# Epoch 8/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0882 - val_loss: 0.0857
# Epoch 9/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0866 - val_loss: 0.0844
# Epoch 10/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0850 - val_loss: 0.0845
# Epoch 11/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0838 - val_loss: 0.0802
# Epoch 12/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0828 - val_loss: 0.0811
# Epoch 13/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0819 - val_loss: 0.0812
# Epoch 14/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0811 - val_loss: 0.0804
# Epoch 15/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0806 - val_loss: 0.0811
# Epoch 16/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0799 - val_loss: 0.0797
# Epoch 17/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0794 - val_loss: 0.0782
# Epoch 18/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0789 - val_loss: 0.0790
# Epoch 19/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0784 - val_loss: 0.0775
# Epoch 20/100
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.0781 - val_loss: 0.0769
# Epoch 21/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0776 - val_loss: 0.0763
# Epoch 22/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0773 - val_loss: 0.0759
# Epoch 23/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0769 - val_loss: 0.0775
# Epoch 24/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0766 - val_loss: 0.0769
# Epoch 25/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0764 - val_loss: 0.0751
# Epoch 26/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0761 - val_loss: 0.0758
# Epoch 27/100
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.0758 - val_loss: 0.0748
# Epoch 28/100
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.0756 - val_loss: 0.0745
# Epoch 29/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0754 - val_loss: 0.0743
# Epoch 30/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0752 - val_loss: 0.0741
# Epoch 31/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0749 - val_loss: 0.0759
# Epoch 32/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0748 - val_loss: 0.0749
# Epoch 33/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0746 - val_loss: 0.0757
# Epoch 34/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0744 - val_loss: 0.0746
# Epoch 35/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0743 - val_loss: 0.0729
# Epoch 36/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0741 - val_loss: 0.0733
# Epoch 37/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0739 - val_loss: 0.0739
# Epoch 38/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0737 - val_loss: 0.0728
# Epoch 39/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0736 - val_loss: 0.0741
# Epoch 40/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0735 - val_loss: 0.0728
# Epoch 41/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0733 - val_loss: 0.0730
# Epoch 42/100
# 60000/60000 [==============================] - 10s 158us/step - loss: 0.0733 - val_loss: 0.0725
# Epoch 43/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0731 - val_loss: 0.0724
# Epoch 44/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0730 - val_loss: 0.0723
# Epoch 45/100
# 60000/60000 [==============================] - 10s 158us/step - loss: 0.0729 - val_loss: 0.0730
# Epoch 46/100
# 60000/60000 [==============================] - 10s 160us/step - loss: 0.0728 - val_loss: 0.0730
# Epoch 47/100
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.0726 - val_loss: 0.0724
# Epoch 48/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0726 - val_loss: 0.0715
# Epoch 49/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0725 - val_loss: 0.0714
# Epoch 50/100
# 60000/60000 [==============================] - 10s 160us/step - loss: 0.0723 - val_loss: 0.0724
# Epoch 51/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0722 - val_loss: 0.0730
# Epoch 52/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.0722 - val_loss: 0.0720
# Epoch 53/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0721 - val_loss: 0.0723
# Epoch 54/100
# 60000/60000 [==============================] - 10s 160us/step - loss: 0.0720 - val_loss: 0.0717
# Epoch 55/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0719 - val_loss: 0.0715
# Epoch 56/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0718 - val_loss: 0.0712
# Epoch 57/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0717 - val_loss: 0.0724
# Epoch 58/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0716 - val_loss: 0.0729
# Epoch 59/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0716 - val_loss: 0.0714
# Epoch 60/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0716 - val_loss: 0.0712
# Epoch 61/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0715 - val_loss: 0.0712
# Epoch 62/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0714 - val_loss: 0.0722
# Epoch 63/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0713 - val_loss: 0.0708
# Epoch 64/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0713 - val_loss: 0.0714
# Epoch 65/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0712 - val_loss: 0.0709
# Epoch 66/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0711 - val_loss: 0.0709
# Epoch 67/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0710 - val_loss: 0.0705
# Epoch 68/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0710 - val_loss: 0.0707
# Epoch 69/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0709 - val_loss: 0.0701
# Epoch 70/100
# 60000/60000 [==============================] - 10s 158us/step - loss: 0.0709 - val_loss: 0.0703
# Epoch 71/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0708 - val_loss: 0.0711
# Epoch 72/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0707 - val_loss: 0.0703
# Epoch 73/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0707 - val_loss: 0.0710
# Epoch 74/100
# 60000/60000 [==============================] - 10s 158us/step - loss: 0.0706 - val_loss: 0.0707
# Epoch 75/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0706 - val_loss: 0.0698
# Epoch 76/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0705 - val_loss: 0.0697
# Epoch 77/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0705 - val_loss: 0.0703
# Epoch 78/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0705 - val_loss: 0.0699
# Epoch 79/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0704 - val_loss: 0.0707
# Epoch 80/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0703 - val_loss: 0.0701
# Epoch 81/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0703 - val_loss: 0.0697
# Epoch 82/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0703 - val_loss: 0.0704
# Epoch 83/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0702 - val_loss: 0.0699
# Epoch 84/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0701 - val_loss: 0.0703
# Epoch 85/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0701 - val_loss: 0.0708
# Epoch 86/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0701 - val_loss: 0.0696
# Epoch 87/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0700 - val_loss: 0.0700
# Epoch 88/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0700 - val_loss: 0.0692
# Epoch 89/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0699 - val_loss: 0.0691
# Epoch 90/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0699 - val_loss: 0.0694
# Epoch 91/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0699 - val_loss: 0.0698
# Epoch 92/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0699 - val_loss: 0.0702
# Epoch 93/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0698 - val_loss: 0.0694
# Epoch 94/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0698 - val_loss: 0.0699
# Epoch 95/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0697 - val_loss: 0.0697
# Epoch 96/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0697 - val_loss: 0.0693
# Epoch 97/100
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0697 - val_loss: 0.0694
# Epoch 98/100
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0696 - val_loss: 0.0697
# Epoch 99/100
# 60000/60000 [==============================] - 10s 172us/step - loss: 0.0697 - val_loss: 0.0691
# Epoch 100/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 0.0695 - val_loss: 0.0693

# %% [markdown]
# # ---------x--- END OF PART 1---x---------

# %% [markdown]
# ---

# %% [markdown]
# ## **PART 2 - Denoising**

# %% [markdown]
# ---

# %% [markdown]
# --

# %% [markdown]
# **Basic Dense Layer**

# %%
from keras.datasets import mnist
from keras.layers import Input
import matplotlib.pyplot as plt
import numpy as np

# Loading DAta and introducing Noise
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 784))
x_test = np.reshape(x_test, (len(x_test), 784))

# Introduce noise with a probability factor of 0.5
noise_factor = 0.5
x_train_noisy = x_train + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_train_noisy = x_train_noisy.astype(np.float32)
x_test_noisy = x_test_noisy.astype(np.float32)

x_train_noisy = np.reshape(x_train_noisy, (x_train_noisy.shape[0], 784))
x_test_noisy = np.reshape(x_test_noisy, (x_test_noisy.shape[0], 784))
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)


# Plot figures to show what the noisy digits look like
n = 10
plt.figure(figsize=(20, 2))
for i in range(n):
    ax = plt.subplot(1, n, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()


input_img = tf.keras.layers.Input(shape=(784,))
print (input_img.shape)

encoded = tf.keras.layers.Dense(128, activation='relu')(input_img)
output_encoded = tf.keras.layers.Dense(128, activation='relu')(encoded)
decoded = tf.keras.layers.Dense(128, activation='relu')(output_encoded)
output_decoded = tf.keras.layers.Dense(784, activation='sigmoid')(decoded)

autoencoder = tf.keras.models.Model(input_img, output_decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.summary()
history = autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test_noisy, x_test))


# For Displaying Plot
plt.plot(range(100), history.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()


# For Displaying Output
#pred = autoencoder.predict(x_test_noisy)
pred = autoencoder.predict(x_test_noisy)
number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test_noisy[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(pred[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# --

# %% [markdown]
# **Using Multi Dense layer for Denoising.**

# %%
from keras.datasets import mnist
from keras.layers import Input
import matplotlib.pyplot as plt
import numpy as np

# Loading DAta and introducing Noise
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 784))
x_test = np.reshape(x_test, (len(x_test), 784))

# Introduce noise with a probability factor of 0.5
noise_factor = 0.5
x_train_noisy = x_train + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_train_noisy = x_train_noisy.astype(np.float32)
x_test_noisy = x_test_noisy.astype(np.float32)

x_train_noisy = np.reshape(x_train_noisy, (x_train_noisy.shape[0], 784))
x_test_noisy = np.reshape(x_test_noisy, (x_test_noisy.shape[0], 784))
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)


# Plot figures to show what the noisy digits look like
n = 10
plt.figure(figsize=(20, 2))
for i in range(n):
    ax = plt.subplot(1, n, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()


input_img = tf.keras.layers.Input(shape=(784,))
print (input_img.shape)

encoded = tf.keras.layers.Dense(128, activation='relu')(input_img)
encoded = tf.keras.layers.Dense(64, activation='relu')(encoded)
encoded = tf.keras.layers.Dense(32, activation='relu')(encoded)
decoded = tf.keras.layers.Dense(32, activation='relu')(encoded)
decoded = tf.keras.layers.Dense(64, activation='relu')(decoded)
decoded = tf.keras.layers.Dense(128, activation='relu')(decoded)
decoded = tf.keras.layers.Dense(784, activation='sigmoid')(decoded)

autoencoder = tf.keras.models.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.summary()
history = autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test_noisy, x_test))


# For Displaying Plot
plt.plot(range(100), history.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()


# For Displaying Output
#pred = autoencoder.predict(x_test_noisy)
pred = autoencoder.predict(x_test_noisy)
number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test_noisy[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(pred[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# --

# %% [markdown]
# **Basic CNN for Denoising.**

# %%
from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

#Basic CNN Model
input_img = tf.keras.layers.Input(shape=(28, 28, 1)) # adapt this if using `channels_first` image data format

x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
decoded = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = tf.keras.models.Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')


# Loading DAta and introducing Noise
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# Introduce noise with a probability factor of 0.5
noise_factor = 0.5
x_train_noisy = x_train + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# Plot figures to show what the noisy digits look like
n = 10
plt.figure(figsize=(20, 2))
for i in range(n):
    ax = plt.subplot(1, n, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()


#Denosing using The Basic CNN Model

history = autoencoder.fit(x_train_noisy, x_train, epochs=100, batch_size=128, 
                shuffle=True, validation_data=(x_test_noisy, x_test), 
                callbacks=[tf.keras.callbacks.TensorBoard(log_dir='./tmp/autoencoder')])

# For Displaying Plot
plt.plot(range(100), history.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()


# For Displaying Output
#pred = autoencoder.predict(x_test)
pred = autoencoder.predict(x_test_noisy)
number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test_noisy[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(pred[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# --

# %% [markdown]
# **Using Complex CNN for Denoising.**

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.layers import Input
from keras.models import Model
from keras import backend as K

input_img = tf.keras.layers.Input(shape=(28, 28, 1))  # adapt this if using `channels_first` image data format

x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(input_img)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
decoded = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = tf.keras.models.Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary()

# Loading DAta and introducing Noise
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# Introduce noise with a probability factor of 0.5
noise_factor = 0.5
x_train_noisy = x_train + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# Plot figures to show what the noisy digits look like
n = 10
plt.figure(figsize=(20, 2))
for i in range(n):
    ax = plt.subplot(1, n, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()



from keras.callbacks import TensorBoard

history = autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test),
                callbacks=[tf.keras.callbacks.TensorBoard(log_dir='/tmp/autoencoder')])


# Plot Graph
plt.plot(range(100), history.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# Input V/S Output
#pred = autoencoder.predict(x_test)
pred = autoencoder.predict(x_test_noisy)
number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test_noisy[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(pred[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# --

# %% [markdown]
# **Using Complex CNN (Keras) for Denoising.**

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model
from keras import backend as K

input_img = Input(shape=(28, 28, 1))  # adapt this if using `channels_first` image data format

x = Conv2D(128, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary()

# Loading DAta and introducing Noise
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# Introduce noise with a probability factor of 0.5
noise_factor = 0.5
x_train_noisy = x_train + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# Plot figures to show what the noisy digits look like
n = 10
plt.figure(figsize=(20, 2))
for i in range(n):
    ax = plt.subplot(1, n, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()



from keras.callbacks import TensorBoard

history = autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/autoencoder')])


# Plot Graph
plt.plot(range(100), history.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# Input V/S Output
#pred = autoencoder.predict(x_test)
pred = autoencoder.predict(x_test_noisy)
number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test_noisy[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(pred[index].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# # ---------x--- END OF PART 2---x---------
